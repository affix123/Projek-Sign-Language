# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # Keypoints Mediapipe Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    #mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    #mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             #mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             #mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             #) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Cam Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_styled_landmarks(frame, results) # apply landmarks
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)) # color conversion

# %% [markdown]
# # Ekstrak Hasil Keypoint

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.37322456
#   y: 0.4667836
#   z: -0.8349531
#   visibility: 0.99987507
# }
# landmark {
#   x: 0.38804764
#   y: 0.38806313
#   z: -0.75325453
#   visibility: 0.9997051
# }
# landmark {
#   x: 0.40535206
#   y: 0.3856567
#   z: -0.7531733
#   visibility: 0.99975413
# }
# landmark {
#   x: 0.42215425
#   y: 0.38352123
#   z: -0.7527689
#   visibility: 0.999705
# }
# landmark {
#   x: 0.3242913
#   y: 0.39960656
#   z: -0.77547705
#   visibility: 0.9997142
# }
# landmark {
#   x: 0.2998877
#   y: 0.40490505
#   z: -0.7747821
#   visibility: 0.99972725
# }
# landmark {
#   x: 0.2769329
#   y: 0.4131223
#   z: -0.77532727
#   visibility: 0.99965554
# }
# landmark {
#   x: 0.44098824
#   y: 0.42163944
#   z: -0.32100135
#   visibility: 0.99972785
# }
# landmark {
#   x: 0.24334514
#   y: 0.45725283
#   z: -0.4003133
#   visibility: 0.99981505
# }
# landmark {
#   x: 0.41309863
#   y: 0.5458578
#   z: -0.672766
#   visibility: 0.99976367
# }
# landmark {
#   x: 0.3366568
#   y: 0.5554915
#   z: -0.6990707
#   visibility: 0.9997971
# }
# landmark {
#   x: 0.59126127
#   y: 0.7411645
#   z: -0.12814316
#   visibility: 0.9990561
# }
# landmark {
#   x: 0.097730845
#   y: 0.8295513
#   z: -0.14005934
#   visibility: 0.9908792
# }
# landmark {
#   x: 0.872299
#   y: 0.96057564
#   z: -0.5962227
#   visibility: 0.7230981
# }
# landmark {
#   x: -0.035322912
#   y: 1.3531834
#   z: -0.03831633
#   visibility: 0.14853914
# }
# landmark {
#   x: 0.7031503
#   y: 0.50587004
#   z: -1.0148923
#   visibility: 0.75046414
# }
# landmark {
#   x: 0.004385197
#   y: 1.7219551
#   z: -0.28927687
#   visibility: 0.08199791
# }
# landmark {
#   x: 0.66279864
#   y: 0.36014262
#   z: -1.1292895
#   visibility: 0.7414941
# }
# landmark {
#   x: -0.0025509638
#   y: 1.8604575
#   z: -0.32822803
#   visibility: 0.107870504
# }
# landmark {
#   x: 0.6258322
#   y: 0.34432092
#   z: -0.9625877
#   visibility: 0.7528811
# }
# landmark {
#   x: 0.033753995
#   y: 1.8343219
#   z: -0.39767346
#   visibility: 0.16159023
# }
# landmark {
#   x: 0.61435354
#   y: 0.406795
#   z: -0.96978396
#   visibility: 0.7510746
# }
# landmark {
#   x: 0.04447152
#   y: 1.7839768
#   z: -0.33233097
#   visibility: 0.17187138
# }
# landmark {
#   x: 0.54016876
#   y: 1.7140056
#   z: -0.05352804
#   visibility: 0.0033094834
# }
# landmark {
#   x: 0.19500542
#   y: 1.7339828
#   z: 0.059622824
#   visibility: 0.0016447754
# }
# landmark {
#   x: 0.56027967
#   y: 2.5102348
#   z: -0.13627
#   visibility: 0.001395432
# }
# landmark {
#   x: 0.2392118
#   y: 2.5178971
#   z: 0.0034739897
#   visibility: 0.00036292095
# }
# landmark {
#   x: 0.57563627
#   y: 3.2091072
#   z: 0.4528118
#   visibility: 5.5294255e-05
# }
# landmark {
#   x: 0.26786697
#   y: 3.2140832
#   z: 0.30950958
#   visibility: 6.758675e-06
#         7.11044848e-01,  5.28172791e-01,  3.30278567e-07,  6.59318984e-01,
#         5.27458668e-01, -2.61308458e-02,  6.13058805e-01,  4.96601224e-01,
#        -4.03324701e-02,  5.93659163e-01,  4.40944225e-01, -5.21499477e-02,
#         5.79569697e-01,  3.85875493e-01, -6.29607141e-02,  6.04450822e-01,
#         3.89553756e-01, -1.82144120e-02,  5.73804319e-01,  3.39130521e-01,
#        -3.73133086e-02,  5.58916807e-01,  3.04215729e-01, -5.45327291e-02,
#         5.48141241e-01,  2.67106712e-01, -6.77447692e-02,  6.32860303e-01,
#         3.55087072e-01, -1.95520464e-02,  6.06775641e-01,  2.80918211e-01,
#        -3.41475755e-02,  5.92260480e-01,  2.33172119e-01, -4.87945005e-02,
#         5.80101371e-01,  1.87912941e-01, -6.05220012e-02,  6.66044474e-01,
#         3.43462855e-01, -2.49213893e-02,  6.49914026e-01,  2.69952208e-01,
#        -4.11383994e-02,  6.40260339e-01,  2.22725511e-01, -5.23366034e-02,
#         6.29345715e-01,  1.78972587e-01, -6.11220635e-02,  7.03549564e-01,
#         3.48001271e-01, -3.28670330e-02,  6.99119925e-01,  2.90819585e-01,
#        -4.73981462e-02,  6.94545746e-01,  2.53990650e-01, -5.30674048e-02,
#         6.86434090e-01,  2.19756946e-01, -5.74084558e-02,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])

# %%
extract_keypoints(results).shape
# Out:
# (258,)

# %% [markdown]
# # Buat Folder Training

# %%
# Path for exported data, numpy arrays
data_path = os.path.join('Dataset') 

# Actions that we try to detect
actions = np.array(['No_Input','A','B','C',"D"])
# X videos worth of data
no_sequences = 30

# Videos are going to be X frames in length
sequence_length = 30

# Folder start
#start_folder = 30

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(data_path, action, str(sequence)))
        except:
            pass

# %% [markdown]
# #  Mengumpulkan Hasil Keypoint dari Gambar

# %%
cap = cv2.VideoCapture(0) #to access webcam device

# set mediapipe model
with mp_holistic.Holistic(min_detection_confidence = 0.5, min_tracking_confidence = 0.5) as holistic:
    #NEW LOOP
    for action in actions: # loop through actions
        for sequence in range(no_sequences): # loop through sequences/videos
            for frame_no in range(sequence_length): # loop through video length 

                # read frames
                ret, frame = cap.read()

                # make detections
                image, results = mediapipe_detection(frame, holistic)

                # draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW collection wait logic
                if frame_no == 0:
                    cv2.putText(image, 'COLLECTING NOW...', (120, 200), 
                                cv2.FONT_HERSHEY_PLAIN, 2, (0, 255, 0), 3, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for Action: {} & Video: {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image) # show image on screen
                    cv2.waitKey(100) # 0.15 seconds break
                else:
                    cv2.putText(image, 'Collecting frames for Action: {} & Video: {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image) # show image on screen
                
                # NEW extract key-points
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(data_path, action, str(sequence), str(frame_no))
                np.save(npy_path, keypoints)
                
                # break gracefully if hit 'q' on keyboard
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
    cap.release()           # release webcam
    cv2.destroyAllWindows() # close down all frames

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(data_path, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(data_path, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape

# %%
np.array(labels).shape

# %%
X = np.array(sequences)

# %%
X.shape

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='tanh', input_shape=(30,258)))
model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 5/5 [==============================] - 9s 626ms/step - loss: 1.5225 - categorical_accuracy: 0.2295
# Epoch 2/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.9987 - categorical_accuracy: 0.6167
# Epoch 3/2000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.7455 - categorical_accuracy: 0.7014
# Epoch 4/2000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5851 - categorical_accuracy: 0.8687
# Epoch 5/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4658 - categorical_accuracy: 0.8472
# Epoch 6/2000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.3779 - categorical_accuracy: 0.8633
# Epoch 7/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3734 - categorical_accuracy: 0.8298
# Epoch 8/2000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.4779 - categorical_accuracy: 0.7590
# Epoch 9/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.3542 - categorical_accuracy: 0.8081
# Epoch 10/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2314 - categorical_accuracy: 0.9001
# Epoch 11/2000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.2146 - categorical_accuracy: 0.9593
# Epoch 12/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2390 - categorical_accuracy: 0.9236
# Epoch 13/2000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.5784 - categorical_accuracy: 0.8598
# Epoch 14/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 0.4702 - categorical_accuracy: 0.8217
# Epoch 15/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.4306 - categorical_accuracy: 0.8472
# Epoch 16/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.3603 - categorical_accuracy: 0.8519
# Epoch 17/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.4343 - categorical_accuracy: 0.8224
# Epoch 18/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.3154 - categorical_accuracy: 0.8930
# Epoch 19/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2503 - categorical_accuracy: 0.9344
# Epoch 20/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2257 - categorical_accuracy: 0.9175
# Epoch 21/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2309 - categorical_accuracy: 0.9205
# Epoch 22/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2997 - categorical_accuracy: 0.9050
# Epoch 23/2000
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1438 - categorical_accuracy: 0.9337
# Epoch 24/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1957 - categorical_accuracy: 0.9564
# Epoch 25/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1472 - categorical_accuracy: 0.9473
# Epoch 26/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2075 - categorical_accuracy: 0.9168
# Epoch 27/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2273 - categorical_accuracy: 0.9337
# Epoch 28/2000
# 5/5 [==============================] - 0s 39ms/step - loss: 0.2505 - categorical_accuracy: 0.9241
# Epoch 29/2000
# 5/5 [==============================] - 0s 41ms/step - loss: 0.2394 - categorical_accuracy: 0.8920
# Epoch 30/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.2790 - categorical_accuracy: 0.9137
# Epoch 31/2000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3992 - categorical_accuracy: 0.8802
# Epoch 32/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 0.2555 - categorical_accuracy: 0.9067
# Epoch 33/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1585 - categorical_accuracy: 0.9523
# Epoch 34/2000
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1200 - categorical_accuracy: 0.9724
# Epoch 35/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 0.1135 - categorical_accuracy: 0.9661
# Epoch 36/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1279 - categorical_accuracy: 0.9567
# Epoch 37/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0885 - categorical_accuracy: 0.9599
# Epoch 38/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0726 - categorical_accuracy: 0.9845
# Epoch 39/2000
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1191 - categorical_accuracy: 0.9564
# Epoch 40/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1446 - categorical_accuracy: 0.9696
# Epoch 41/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1711 - categorical_accuracy: 0.9512
# Epoch 42/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3126 - categorical_accuracy: 0.9154
# Epoch 43/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1548 - categorical_accuracy: 0.9553
# Epoch 44/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1463 - categorical_accuracy: 0.9544
# Epoch 45/2000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0935 - categorical_accuracy: 0.9812
# Epoch 46/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0783 - categorical_accuracy: 0.9696
# Epoch 47/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0792 - categorical_accuracy: 0.9676
# Epoch 48/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0761 - categorical_accuracy: 0.9739
# Epoch 49/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0931 - categorical_accuracy: 0.9718
# Epoch 50/2000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1576 - categorical_accuracy: 0.9419
# Epoch 51/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.9561 - categorical_accuracy: 0.7686
# Epoch 52/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.5645 - categorical_accuracy: 0.7963
# Epoch 53/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.4229 - categorical_accuracy: 0.7819
# Epoch 54/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.7090 - categorical_accuracy: 0.8296
# Epoch 55/2000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.1342 - categorical_accuracy: 0.9687
# Epoch 56/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2242 - categorical_accuracy: 0.8939
# Epoch 57/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1926 - categorical_accuracy: 0.9415
# Epoch 58/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1667 - categorical_accuracy: 0.9246
# Epoch 59/2000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0999 - categorical_accuracy: 0.9946
# Epoch 60/2000
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0888 - categorical_accuracy: 0.9767
# Epoch 61/2000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.1543 - categorical_accuracy: 0.9532
# Epoch 62/2000
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0453 - categorical_accuracy: 0.9964
# Epoch 63/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0779 - categorical_accuracy: 0.9814
# Epoch 64/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0722 - categorical_accuracy: 0.9757
# Epoch 65/2000
# 5/5 [==============================] - 0s 43ms/step - loss: 0.1546 - categorical_accuracy: 0.9272
# Epoch 66/2000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0795 - categorical_accuracy: 0.9891
# Epoch 67/2000
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0373 - categorical_accuracy: 1.0000
# Epoch 68/2000
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0434 - categorical_accuracy: 0.9923
# Epoch 69/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 0
- categorical_accuracy: 1.0000
# Epoch 397/2000
# 5/5 [==============================] - 0s 42ms/step - loss: 5.4484e-04 - categorical_accuracy: 1.0000
# Epoch 398/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.5082e-04 - categorical_accuracy: 1.0000
# Epoch 399/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 5.6052e-04 - categorical_accuracy: 1.0000
# Epoch 400/2000
# 5/5 [==============================] - 0s 43ms/step - loss: 5.5801e-04 - categorical_accuracy: 1.0000
# Epoch 401/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 5.4863e-04 - categorical_accuracy: 1.0000
# Epoch 402/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 5.4085e-04 - categorical_accuracy: 1.0000
# Epoch 403/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 5.4523e-04 - categorical_accuracy: 1.0000
# Epoch 404/2000
# 5/5 [==============================] - 0s 48ms/step - loss: 5.2782e-04 - categorical_accuracy: 1.0000
# Epoch 405/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 5.3216e-04 - categorical_accuracy: 1.0000
# Epoch 406/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 5.2502e-04 - categorical_accuracy: 1.0000
# Epoch 407/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.2795e-04 - categorical_accuracy: 1.0000
# Epoch 408/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 5.4284e-04 - categorical_accuracy: 1.0000
# Epoch 409/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.0253e-04 - categorical_accuracy: 1.0000
# Epoch 410/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.3798e-04 - categorical_accuracy: 1.0000
# Epoch 411/2000
# 5/5 [==============================] - 0s 38ms/step - loss: 5.1917e-04 - categorical_accuracy: 1.0000
# Epoch 412/2000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.2238e-04 - categorical_accuracy: 1.0000
# Epoch 413/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.2098e-04 - categorical_accuracy: 1.0000
# Epoch 414/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 5.1276e-04 - categorical_accuracy: 1.0000
# Epoch 415/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 4.9807e-04 - categorical_accuracy: 1.0000
# Epoch 416/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 4.9950e-04 - categorical_accuracy: 1.0000
# Epoch 417/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 4.9323e-04 - categorical_accuracy: 1.0000
# Epoch 418/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.0296e-04 - categorical_accuracy: 1.0000
# Epoch 419/2000
# ...
# Epoch 1867/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.2627e-06 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.6854e-06 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 5/5 [==============================] - 0s 39ms/step - loss: 7.8042e-06 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.3958e-06 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.7557e-06 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.5280e-06 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 7.5603e-06 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 7.5542e-06 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 7.3974e-06 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 7.5669e-06 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 7.5631e-06 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 7.5735e-06 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 7.1528e-06 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 7.5274e-06 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 7.3362e-06 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.2943e-06 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.2459e-06 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 5/5 [==============================] - 0s 30ms/step - loss: 7.1937e-06 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 7.1549e-06 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 7.1614e-06 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.1817e-06 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 7.3635e-06 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.0526e-06 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.9863e-06 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.0680e-06 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 5/5 [==============================] - 0s 42ms/step - loss: 7.0404e-06 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 6.7532e-06 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.0798e-06 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.0034e-06 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 7.0089e-06 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.2739e-06 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 5/5 [==============================] - ETA: 0s - loss: 7.2078e-06 - categorical_accuracy: 1.00 - 0s 40ms/step - loss: 7.1563e-06 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 6.9786e-06 - categorical_accuracy: 1.0000 0s - loss: 6.9634e-06 - categorical_accuracy: 1.
# Epoch 1900/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 7.0136e-06 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 7.2036e-06 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.9882e-06 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.1258e-06 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 7.2574e-06 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.8418e-06 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.9560e-06 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.9839e-06 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 7.1523e-06 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.9068e-06 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.8175e-06 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.7728e-06 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 6.8921e-06 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 6.8274e-06 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 6.7571e-06 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 6.8971e-06 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.6794e-06 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.7874e-06 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.6422e-06 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.7048e-06 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 5/5 [==============================] - 0s 39ms/step - loss: 6.4778e-06 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.7344e-06 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.3827e-06 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.4894e-06 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.5655e-06 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.6205e-06 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.4910e-06 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.5411e-06 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.4793e-06 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.5438e-06 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.7655e-06 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.3374e-06 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 6.3065e-06 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.4793e-06 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.3999e-06 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.5849e-06 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.2810e-06 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.2904e-06 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.3352e-06 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.3402e-06 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.0266e-06 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.1350e-06 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.3288e-06 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 6.2961e-06 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.3868e-06 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.1126e-06 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 6.1371e-06 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.4019e-06 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.9472e-06 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 6.3470e-06 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.0496e-06 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.1560e-06 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.3405e-06 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.9205e-06 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.1753e-06 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 6.0811e-06 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.0965e-06 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.8833e-06 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 5.9895e-06 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.8867e-06 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 6.0544e-06 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 6.0699e-06 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 6.1009e-06 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.7942e-06 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.9751e-06 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 6.0779e-06 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.6828e-06 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 6.0288e-06 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 5.8267e-06 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.6941e-06 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.8056e-06 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.7424e-06 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 5.9305e-06 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 5/5 [==============================] - 0s 38ms/step - loss: 6.0768e-06 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 5.7883e-06 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.7704e-06 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.7245e-06 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.8078e-06 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 5.9631e-06 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 5.4214e-06 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.6163e-06 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 5.4686e-06 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 5.7319e-06 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 5.4115e-06 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 5/5 [==============================] - 0s 33ms/step - loss: 5.6433e-06 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.6549e-06 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.5024e-06 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.6563e-06 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.6880e-06 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 5.5322e-06 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 5/5 [==============================] - 0s 36ms/step - loss: 5.7045e-06 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 5.5201e-06 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.4716e-06 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.2687e-06 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 5/5 [==============================] - 0s 31ms/step - loss: 5.3347e-06 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 5.3187e-06 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 5/5 [==============================] - 0s 39ms/step - loss: 5.6377e-06 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 5/5 [==============================] - 0s 37ms/step - loss: 5.3469e-06 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 5/5 [==============================] - 0s 35ms/step - loss: 5.3213e-06 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 5/5 [==============================] - 0s 32ms/step - loss: 5.3302e-06 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 5/5 [==============================] - 0s 34ms/step - loss: 5.4732e-06 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 30, 64)            82688
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 237,317
# Trainable params: 237,317
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[6, 0],
#         [0, 2]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[7, 0],
#         [0, 1]],
#
#        [[6, 0],
#         [0, 2]],
#
#        [[6, 0],
#         [0, 2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
#colors = [(245,117,16), (117,245,16), (16,117,245)]
#def prob_viz(res, actions, input_frame, colors):
    #output_frame = input_frame.copy()
    #for num, prob in enumerate(res):
        #cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        #cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    #return output_frame

# %%
#plt.figure(figsize=(18,18))
#plt.imshow(prob_viz(res, actions, image, colors))

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.99

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            #image = prob_viz(res, actions, image, colors)
            
        #cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# D
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# A
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# B
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# C
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# No_Input
